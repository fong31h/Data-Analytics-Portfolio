# %% [markdown]
# ### Now I'm gonna get more of the same decklists for the other expansions

# %%
from Scrape_pokemon_functions import *

# %%
url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A1a'

# %%
create_2_df
# Out:
# <function Scrape_pokemon_functions.create_2_df(soup)>

# %%
soups = cook_soups(url)
