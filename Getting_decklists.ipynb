# %% [markdown]
# ## Okay time to get the decklists

# %%
import importlib
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import re
from io import StringIO

# %%
import Scrape_pokemon_functions as sp
importlib.reload(sp)
import Scrape_pokemon_functions as sp

# %%
index = ['ga', 'mi', 'sts', 'tl', 'sr', 'cg', 'edc', 'eg', 'wss', 'ss']

# %%
all_2s = {k:pd.read_csv(f'../Data_Files/{v}.csv') for k,v in zip(index, names)}

# %% [markdown]
# #### I updated all_2s manually using sp.add_decklist_column()

# %%
all_2s['ss'].columns
# Out:
# Index(['Deck', 'Player', 'Date', 'Tournament', 'Placement', 'Player_Total',
#        'Score', 'Decklist_url', 'Tournament_url', 'Decklists'],
#       dtype='object')

# %% [markdown]
# #### The problem is that this data can't really be written to file super well
# #### so we will use to_json()

# %%
all_2s['ga'].to_csv('../Data_Files/A1_all_2s.csv',index=False)

# %%
all_2s['mi']['Decklists'] = sp.convert_to_json(all_2s['mi']['Decklists'])
all_2s['mi'].to_csv('../Data_Files/A1a_all_2s.csv',index=False)

# %%
all_2s['sts']['Decklists'] = sp.convert_to_json(all_2s['sts']['Decklists'])
all_2s['sts'].to_csv('../Data_Files/A2_all_2s.csv',index=False)

# %%
all_2s['tl']['Decklists'] = sp.convert_to_json(all_2s['tl']['Decklists'])
all_2s['tl'].to_csv('../Data_Files/A2a_all_2s.csv',index=False)

# %%
all_2s['sr']['Decklists'] = sp.convert_to_json(all_2s['sr']['Decklists'])
all_2s['sr'].to_csv('../Data_Files/A2b_all_2s.csv',index=False)

# %%
all_2s['cg']['Decklists'] = sp.convert_to_json(all_2s['cg']['Decklists'])
all_2s['cg'].to_csv('../Data_Files/A3_all_2s.csv',index=False)

# %%
all_2s['edc']['Decklists'] = sp.convert_to_json(all_2s['edc']['Decklists'])
all_2s['edc'].to_csv('../Data_Files/A3a_all_2s.csv',index=False)

# %%
all_2s['eg']['Decklists'] = sp.convert_to_json(all_2s['eg']['Decklists'])
all_2s['eg'].to_csv('../Data_Files/A3b_all_2s.csv',index=False)

# %%
all_2s['wss']['Decklists'] = sp.convert_to_json(all_2s['wss']['Decklists'])
all_2s['wss'].to_csv('../Data_Files/A4_all_2s.csv',index=False)

# %%
all_2s['ss']['Decklists'] = sp.convert_to_json(all_2s['ss']['Decklists'])
all_2s['ss'].to_csv('../Data_Files/A4a_all_2s.csv',index=False)

# %% [markdown]
# #### Then I use read_json(StringIO(object)) to bring it back as a data frame

# %% [markdown]
# Okay I'm done with data gathering and cleaning now. Time to think about visuals and presentation and dashboard, etc.
#
# Wow!

# %% [markdown]
# ### So I had to re-scrape all the decklists. I'm going to fix the main one, dropdown_df.csv,
# ### but I don't care that much about the individual ones, A1_all_2s, etc. so I won't fix those columns right now

# %%
df = pd.read_csv('Data_Files/dropdown_df.csv')

# %%
df
# Out:
#                           Deck          Player        Date  \
# 0          Mewtwo ex Gardevoir       MojoSueco  2024-11-23
# 1          Mewtwo ex Gardevoir         Hanamon  2024-11-16
# 2          Mewtwo ex Gardevoir        Sigphale  2024-11-23
# 3          Mewtwo ex Gardevoir         Marcoca  2024-12-07
# 4          Mewtwo ex Gardevoir        Tuborizm  2024-12-14
# ...                        ...             ...         ...
# 38987         Togekiss Banette   Mistymigraine  2025-10-13
# 38988   Poliwrath ex Shiinotic    Just For Fun  2025-09-02
# 38989        Altaria Celebi ex      GarboHanzo  2025-10-10
# 38990         Dugtrio Primeape  Pokemaninjapan  2025-09-05
# 38991  Leafeon ex Decidueye ex   petalsrequiem  2025-09-19
#
#                                            Tournament  Placement  \
# 0         Ursiiday's Pocket Weekly #4 • 400 USD Prize        1.0
# 1         Ursiiday's Pocket Weekly #3 • 400 USD Prize        1.0
# ...
