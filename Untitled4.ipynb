# %% [markdown]
# ### Now I'm gonna get more of the same decklists for the other expansions

# %%
import pandas as pd
import importlib
import Scrape_pokemon_functions as sp

# %%
import Scrape_pokemon_functions as sp
importlib.reload(sp)
import Scrape_pokemon_functions as sp

# %%
a1 = pd.read_csv('Data_Files/A1_full_1.csv')

# %%
link_list = a1['Deck_links']

# %%
soups = sp.cook_soups(link_list)

# %%
mi_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A1a'

# %%
df = sp.create_1_df(url)

# %%
a1a = df

# %%
a1a.to_csv('../Data_Files/A1a_full_1.csv',index=False)

# %%
link_list = df['Deck_links']

# %%
soups = cook_soups(link_list)

# %%
a1a_2s = create_2_dfs(soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:79: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   regex = re.compile(r"(\d{0,4})[a-z]{2} of (\d{0,4})")

# %%
a1a_2s.to_csv('../Data_Files/A1a_all_2s.csv',index=False)

# %% [markdown]
# ## Spacetime Smackdown

# %%
sts_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A2'

# %%
a1b = sp.create_1_df(sts_url)

# %%
a2 = a1b

# %%
a2.to_csv('../Data_Files/A2_full_1.csv')

# %%
sts_link_list = a2['Deck_links']

# %%
soups = sp.cook_soups(sts_link_list)

# %%
a2_2s = sp.create_2_dfs(soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:104: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(df_list).reset_index(drop=True)

# %%
a2_2s.to_csv('../Data_Files/A2_all_2s.csv',index=False)

# %% [markdown]
# ## Triumphant Light

# %%
tl_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A2a'

# %%
a2a = sp.create_1_df(tl_url)

# %%
a2a.to_csv('../Data_Files/A2a_full_1.csv',index=False)

# %%
tl_link_list = a2a['Deck_links']

# %%
tl_soups = sp.cook_soups(tl_link_list)

# %%
a2a_2s = sp.create_2_dfs(tl_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a2a_2s.to_csv('../Data_Files/A2a_all_2s.csv',index=False)

# %% [markdown]
# ### Shining Revelry

# %%
sr_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A2b'

# %%
a2b = sp.create_1_df(sr_url)

# %%
a2b.to_csv('../A2b_full_1.csv',index=False)

# %%
sr_link_list = a2b['Deck_links']

# %%
sr_soups = sp.cook_soups(sr_link_list)

# %%
a2b_2s = sp.create_2_dfs(sr_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a2b_2s.to_csv('../Data_Files/A2b_all_2s.csv',index=False)

# %% [markdown]
# ### Celestial Guardians

# %%
cg_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A3'

# %%
a3 = sp.create_1_df(cg_url)

# %%
a3.to_csv('../Data_Files/A3_full_1.csv',index=False)

# %%
cg_link_list = a3['Deck_links']

# %%
cg_soups = sp.cook_soups(cg_link_list)

# %%
a3_2s = sp.create_2_dfs(cg_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a3_2s.to_csv('../Data_Files/A3_all_2s.csv',index=False)

# %% [markdown]
# ### Extra Dimensional Crisis

# %%
ed_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A3a'

# %%
a3a = sp.create_1_df(ed_url)

# %%
a3a.to_csv('../Data_Files/A3_full_1.csv',index=False)

# %%
ed_link_list = a3a['Deck_links']

# %%
ed_soups = sp.cook_soups(ed_link_list)

# %%
a3a_2s = sp.create_2_dfs(ed_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a3a_2s.to_csv('../Data_Files/A3a_all_2s.csv',index=False)

# %% [markdown]
# ### Eevee Grove

# %%
eg_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A3b'

# %%
a3b = sp.create_1_df(eg_url)

# %%
a3b.to_csv('../Data_Files/A3b_full_1.csv',index=False)

# %%
eg_link_list = a3b['Deck_links']

# %%
eg_soups = sp.cook_soups(eg_link_list)

# %%
a3b_2s = sp.create_2_dfs(eg_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a3b_2s.to_csv('../Data_Files/A3b_all_2s.csv',index=False)

# %% [markdown]
# ### Wisdom of Sea and Sky

# %%
wss_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A4'

# %%
a4 = sp.create_1_df(wss_url)

# %%
a4.to_csv('../Data_Files/A4_full_1.csv',index=False)

# %%
wss_link_list = a4['Deck_links']

# %%
wss_soups = sp.cook_soups(wss_link_list)

# %%
a4_2s = sp.create_2_dfs(wss_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a4_2s.to_csv('../Data_Files/A4_all_2s.csv',index=False)

# %% [markdown]
# ### Secluded Springs

# %%
ss_link = 'https://play.limitlesstcg.com/decks?game=POCKET&set=A4a'

# %%
a4a = sp.create_1_df(ss_link)

# %%
a4a.to_csv('../Data_Files/A4a_full_1.csv',index=False)

# %%
ss_link_list = a4a['Deck_links']

# %%
ss_soups = sp.cook_soups(ss_link_list)

# %%
a4a_2s = sp.create_2_dfs(ss_soups)
# Out:
# /Users/spencerfong/DS_Project/my_env/Scrape_pokemon_functions.py:107: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %%
a4a_2s.to_csv('../Data_Files/A4a_all_2s.csv',index=False)

# %% [markdown]
# ### Mega Rising

# %%
b1_url = 'https://play.limitlesstcg.com/decks?game=POCKET&set=B1'

# %%
b1 = sp.create_1_df(b1_url)

# %%
b1.head()
# Out:
#                           Deck Count  Share              Score Win_Percentage  \
# 0       Suicune ex Greninja ex  1816  9.40%  5208 - 4555 - 162         52.47%
# 1  Mega Altaria ex Indeedee ex  1793  9.28%  5287 - 4535 - 205         52.73%
# 2      Hydreigon Mega Absol ex  1584  8.20%  4372 - 4005 - 191         51.03%
# 3     Mega Absol ex Darkrai ex  1420  7.35%  3936 - 3521 - 162         51.66%
# 4     Mega Blaziken ex Heatmor  1098  5.68%  3174 - 2846 - 125         51.65%
#
#                                           Deck_links
# 0  /decks/suicune-ex-a4a-greninja-ex-b1?game=POCK...
# 1  /decks/mega-altaria-ex-indeedee-ex-b1?game=POC...
# 2  /decks/hydreigon-mega-absol-ex-b1?game=POCKET&...
# 3  /decks/mega-absol-ex-b1-darkrai-ex-a2?game=POC...
# 4  /decks/mega-blaziken-ex-heatmor-b1?game=POCKET...

# %%
pd.read_csv('../Data_Files/A4a_all_2s.csv')
# Out:
#                          Deck                  Player        Date  \
# 0         Suicune ex Greninja     FrogEX | Numatinale  2025-10-04
# 1         Suicune ex Greninja                Hamza007  2025-09-01
# 2         Suicune ex Greninja                Liamkrew  2025-09-11
# 3         Suicune ex Greninja               Danimaton  2025-09-07
# 4         Suicune ex Greninja  sZero | frappesdrinker  2025-09-18
# ...                       ...                     ...         ...
# 3912         Togekiss Banette           Mistymigraine  2025-10-13
# 3913   Poliwrath ex Shiinotic            Just For Fun  2025-09-02
# 3914        Altaria Celebi ex              GarboHanzo  2025-10-10
# 3915         Dugtrio Primeape          Pokemaninjapan  2025-09-05
# 3916  Leafeon ex Decidueye ex           petalsrequiem  2025-09-19
#
#                                           Tournament  Placement  Player_Total  \
# 0             PocketMads - $100 Pocket Tournament #2        1.0         336.0
# ...
