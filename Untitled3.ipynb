# %% [markdown]
# ### Now we try to get each 2 from all of 1

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import re
import os
import time

# %%
a1_2s[(a1_2s['Placement'] >= 1) & (a1_2s['Placement'] <= 1) & (a1_2s['Player_Total'] >= 1)]['Deck'].unique()
# Out:
# array(['Mewtwo ex Gardevoir', 'Pikachu ex Zebstrika',
#        'Charizard ex Moltres ex', 'Pikachu ex Raichu',
#        'Pikachu ex Electrode', 'Charizard ex Arcanine ex',
#        'Starmie ex Articuno ex', 'Pikachu ex Zapdos ex', 'Arbok Weezing',
#        'Ninetales Rapidash', 'Articuno ex Greninja',
#        'Starmie ex Greninja', 'Marowak ex Sandslash',
#        'Venusaur ex Exeggutor ex', 'Wigglytuff ex Arbok',
#        'Marowak ex Primeape', 'Articuno ex', 'Gardevoir Mewtwo ex',
#        'Starmie ex Golduck', 'Muk Weezing', 'Wigglytuff ex Exeggutor ex',
#        'Machamp ex Primeape', 'Blastoise ex Blastoise',
#        'Machoke Graveler', 'Starmie ex Frosmoth', 'Dragonite Hypno',
#        'Greninja Wigglytuff ex', 'Zapdos ex Jolteon',
#        'Blastoise ex Articuno', 'Zapdos ex Golbat', 'Greninja Bruxish',
#        'Wigglytuff ex Articuno ex', 'Greninja Lapras'], dtype=object)

# %%
a1_2s[(a1_2s['Deck'].str.contains('Dragonite')) & (a1_2s['Placement'] < 64) & (a1_2s['Player_Total'] >= 200)]
# Out:
#                          Deck        Player        Date  \
# 380         Dragonite Weezing      copiclol  2024-11-13
# 382         Dragonite Weezing       DorgoBR  2024-12-04
# 383         Dragonite Weezing    knullified  2024-11-13
# 384         Dragonite Weezing       Yamirai  2024-12-01
# 385         Dragonite Weezing  Sacredpunish  2024-11-04
# 389         Dragonite Weezing       Thiheen  2024-11-13
# 391         Dragonite Weezing          xopy  2024-11-13
# 393         Dragonite Weezing       saisoul  2024-11-02
# 394         Dragonite Weezing      gochunky  2024-11-25
# 399         Dragonite Weezing       Taabouu  2024-11-13
# 780        Dragonite Frosmoth    inspectred  2024-11-13
# 980      Dragonite Kangaskhan      GigaGoat  2024-12-04
# 1421                Dragonite     tl_spruce  2024-11-13
# 1422                Dragonite       amko_ex  2024-12-04
# 1423                Dragonite        kitus4  2024-11-19
# 1425                Dragonite     tl_spruce  2024-12-04
# ...
