# %%
import pandas as pd
import Scrape_pokemon_functions as sp
import importlib
import re

# %%
import Scrape_pokemon_functions as sp
importlib.reload(sp)
import Scrape_pokemon_functions as sp

# %%
dropdown_df = pd.read_csv('Data_Files/dropdown_df.csv')

# %%
def filter_nonex_frame(df, cardid):
    indices = []
    for i in range(len(df['Decklists'])):
        f = df['Decklists'][i].find(f'({cardid})')
        if f != -1:
            indices.append(i)
    return df.iloc[indices]

# %%
cardid = "A1-1"

# %%
def function(df, cardid):
    regex = re.compile(r'A[1234][ab]?-\d{1,3}')
    if re.match(regex, cardid):
        df = filter_nonex_frame(df, cardid)
    else:
        df = df[df['Decklists']].str.contains(cardid)
    return df

# %%
function(dropdown_df, cardid)
# Out:
#                            Deck       Player        Date  \
# 260    Venusaur ex Exeggutor ex    SolidKrom  2024-12-13
# 261    Venusaur ex Exeggutor ex   LUKAS_FL99  2024-12-16
# 262    Venusaur ex Exeggutor ex      Mora898  2024-11-28
# 263    Venusaur ex Exeggutor ex        Rizzo  2024-10-27
# 264    Venusaur ex Exeggutor ex   Landeythan  2024-12-04
# ...                         ...          ...         ...
# 38654         Venusaur ex Pichu     Briscard  2025-09-23
# 38676    Leafeon ex Venusaur ex  quetzalyami  2025-10-24
# 38848     Venusaur ex Lilligant   OlivineOil  2025-09-06
# 38892    Venusaur ex Wigglytuff  igotochurch  2025-10-21
# 38965  Venusaur ex Exeggutor ex      Anashee  2025-10-18
#
#                                             Tournament  Placement  \
# 260             Pokémon Millennium Pocket Free Tour #2        1.0
# 261                           #1 POCKET CHAMPION'S CUP        3.0
# 262                        🌿 Team Rocket Poket Cup #14        4.0
# ...

# %%
regex = re.compile(r'A[1234][ab]?-\d{1,3}')
if re.match(regex, cardid):
    print("Yeppers")
else:
    print("No")
# Out:
# No

# %%
function(dropdown_df, cardid)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 function(dropdown_df, cardid)
#
# Cell In[163], line 6, in function(df, cardid)
#       4     df = filter_nonex_frame(dropdown_df, cardid)
#       5 else:
# ----> 6     df = dropdown_df[dropdown_df['Decklists']].str.contains(cardid)
#
# File ~/DS_Project/my_env/lib/python3.14/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/DS_Project/my_env/lib/python3.14/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...
